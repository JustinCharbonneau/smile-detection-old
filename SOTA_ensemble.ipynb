# %%
# Mount google drive
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# Import libraries and ignore warnings
import warnings
warnings.filterwarnings('ignore')
from tensorflow import set_random_seed
import pandas as pd
import numpy as np
np.random.seed(2)

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# Plot architecture
import keras
import pydot
from keras.utils.vis_utils import model_to_dot

from keras import models
from keras import layers
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.preprocessing import image

import os
from PIL import Image
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.

# %%
# Read the annotations file that contains the label and the image file name
labels = pd.read_csv('gdrive/My Drive/Colab Notebooks/Computer Vision/SMILE_Dataset/annotations.csv', header=None, names=['fname','label'])

# Shuffle data
labels = labels.sample(frac=1).reset_index()

# Use a list comprehension to loop over image file names and import one by one and store pixel values
x = np.array([image.img_to_array(image.load_img('gdrive/My Drive/Colab Notebooks/Computer Vision/SMILE_Dataset/all/'+fname[:-3]+'jpg', target_size=(96, 96))) for fname in labels['fname']])

# Because the names are strings, the neural network only takes in numerical formats so we will one-hot encode the label
label_encoder = LabelEncoder()
integer_encoded = label_encoder.fit_transform(labels['label'])
y = integer_encoded

# %%
def akshay():
    
    model = models.Sequential()
    model.add(layers.Flatten(input_shape=(96, 96, 3)))
    model.add(layers.Dense(80, activation='relu'))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(32, activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    
    # Compile model
    model.compile(loss='binary_crossentropy',
                  optimizer=optimizers.Adam(lr=0.001),
                  metrics=['acc'])
    
    return model

# %%
def last_time():
    """
    """
    
    model = models.Sequential()
    
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(96, 96, 3)))
    model.add(layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D())
    model.add(layers.Dropout(0.1))
    
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D())
    model.add(layers.Dropout(0.1))

    # Feed to a densily connected layer for prediction
    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dropout(0.2))

    model.add(layers.Dense(32, activation='relu'))
    model.add(layers.Dropout(0.2))

    model.add(layers.Dense(1, activation='sigmoid'))
    
    # Compile model
    model.compile(loss='binary_crossentropy',
                  optimizer=optimizers.Adam(lr=0.001),
                  metrics=['acc'])
    
    return model

# %%
def sota_1():
    """
    Reaches about 96%. This is the best architecture so far.
    """
    
    model = models.Sequential()
    
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(96, 96, 3)))
    model.add(layers.MaxPooling2D((2, 2)))
    
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    
    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    
    model.add(layers.Conv2D(256, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))

    # Feed to a densily connected layer for prediction
    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(1, activation='sigmoid'))
    
    # Compile model
    model.compile(loss='binary_crossentropy',
                  #optimizer=optimizers.RMSprop(lr=1e-4), 91.93%
                  optimizer=optimizers.Adam(lr=0.001),
                  metrics=['acc'])
    
    return model

# %%
# All classification reports will be added here. When we are done we can average the f1 scores
reports = []
np.random.seed(2) # numpy seed generator
set_random_seed(2) # Tensorflow seed generator
# Apply stratified K-fold ith 10 splits. Stratified means the same distribution of classes than the whole dataset
# In this case, 50-50
kf = StratifiedKFold(n_splits=10)


# Just for printing purposes
id = 1

for train_index, test_index in kf.split(x,y):
    np.random.seed(2) # numpy seed generator
    set_random_seed(2) # Tensorflow seed generator

    print('Kfold iteration {}/10'.format(id))
    print('Total images: {} ---- Train images: {} ---- Test images: {}'.format(len(x),len(train_index),len(test_index)))
    id += 1 

    X_train, X_test = x[train_index], x[test_index]
    y_train, y_test = y[train_index], y[test_index]

    

    # We identified some optimal affine transformations
    datagen1 = ImageDataGenerator(rescale=1./255,
                                 rotation_range=20, # randomly rotate images in the range (degrees, 0 to 180)
                                 width_shift_range=0.1, # randomly shift images horizontally (fraction of total width)
                                 height_shift_range=0.1, 
                                 shear_range=0.1,
                                 zoom_range=0.2)

    datagen1.fit(X_train)

    datagen2 = ImageDataGenerator(rescale=1./255,
                                 rotation_range=40, # randomly rotate images in the range (degrees, 0 to 180)
                                 width_shift_range=0.2, # randomly shift images horizontally (fraction of total width)
                                 height_shift_range=0.2, 
                                 shear_range=0.3,
                                 zoom_range=0.4)

    datagen2.fit(X_train)

    learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', 
                                            patience=3, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

    # Ensemble Learning
    ensemble_predictions = {}
    for i in range(2):
        print("training model:",i)
        model = last_time()
        history = model.fit_generator(datagen1.flow(X_train, y_train, batch_size = 16), epochs = 30, 
                              validation_data = (X_test,y_test), steps_per_epoch=len(X_train) / 16,
                              callbacks=[learning_rate_reduction])
        
        y_pred_test = model.predict(X_test)
        y_pred_test = y_pred_test.astype(int) # Convert float to int
        y_pred_test = y_pred_test.reshape(y_pred_test.shape[0]) # Reshape

        ensemble_predictions['last_time_'+str(i)] = y_pred_test

    for i in range(2):
        print("training model:",i)
        model = akshay()
        history = model.fit_generator(datagen1.flow(X_train, y_train, batch_size = 16), epochs = 20, 
                              validation_data = (X_test,y_test), steps_per_epoch=len(X_train) / 16,
                              callbacks=[learning_rate_reduction])
        
        y_pred_test = model.predict(X_test)
        y_pred_test = y_pred_test.astype(int) # Convert float to int
        y_pred_test = y_pred_test.reshape(y_pred_test.shape[0]) # Reshape

        ensemble_predictions['akshay_'+str(i)] = y_pred_test

    for i in range(3):
        print("training model:",i)
        model = sota_1()
        history = model.fit_generator(datagen1.flow(X_train, y_train, batch_size = 16), epochs = 20, 
                              validation_data = (X_test,y_test), steps_per_epoch=len(X_train) / 16,
                              callbacks=[learning_rate_reduction])
        
        y_pred_test = model.predict(X_test)
        y_pred_test = y_pred_test.astype(int) # Convert float to int
        y_pred_test = y_pred_test.reshape(y_pred_test.shape[0]) # Reshape

        ensemble_predictions['sota_1_'+str(i)] = y_pred_test

    ensemble_df = pd.DataFrame(ensemble_predictions)

    temp_test = ensemble_df.mode(axis=1)[0]

    #print(classification_report(y_test, y_pred))
    reports.append(classification_report(y_test, temp_test,output_dict=True))
# Out:
# Kfold iteration 1/10
# Total images: 400 ---- Train images: 360 ---- Test images: 40
# training model 1
# training model: 0
# Epoch 1/30
# 23/22 [==============================] - 9s 403ms/step - loss: 0.6972 - acc: 0.5221 - val_loss: 1.6480 - val_acc: 0.5000
# Epoch 2/30
# 23/22 [==============================] - 1s 39ms/step - loss: 0.6489 - acc: 0.5952 - val_loss: 4.3842 - val_acc: 0.7250
# Epoch 3/30
# 23/22 [==============================] - 1s 56ms/step - loss: 0.5213 - acc: 0.7583 - val_loss: 2.7903 - val_acc: 0.8250
# Epoch 4/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.3255 - acc: 0.8586 - val_loss: 1.5942 - val_acc: 0.9000
# Epoch 5/30
# 23/22 [==============================] - 1s 56ms/step - loss: 0.3149 - acc: 0.8696 - val_loss: 2.3914 - val_acc: 0.8500
# Epoch 6/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.2831 - acc: 0.8996 - val_loss: 1.1669 - val_acc: 0.9250
# Epoch 7/30
# 23/22 [==============================] - 1s 57ms/step - loss: 0.2362 - acc: 0.9048 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 8/30
# 23/22 [==============================] - 1s 56ms/step - loss: 0.2511 - acc: 0.9102 - val_loss: 0.8059 - val_acc: 0.9500
# Epoch 9/30
# 23/22 [==============================] - 1s 57ms/step - loss: 0.2167 - acc: 0.9158 - val_loss: 1.2045 - val_acc: 0.9250
# Epoch 10/30
# 23/22 [==============================] - 1s 56ms/step - loss: 0.2027 - acc: 0.9348 - val_loss: 3.1316 - val_acc: 0.8000
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 11/30
# 23/22 [==============================] - 1s 41ms/step - loss: 0.1854 - acc: 0.9293 - val_loss: 0.8059 - val_acc: 0.9500
# Epoch 12/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.1561 - acc: 0.9294 - val_loss: 0.8059 - val_acc: 0.9500
# Epoch 13/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.1426 - acc: 0.9487 - val_loss: 1.6118 - val_acc: 0.9000
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 14/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.1553 - acc: 0.9483 - val_loss: 2.8207 - val_acc: 0.8250
# Epoch 15/30
# 23/22 [==============================] - 1s 56ms/step - loss: 0.1523 - acc: 0.9321 - val_loss: 0.8059 - val_acc: 0.9500
# Epoch 16/30
# 23/22 [==============================] - 1s 57ms/step - loss: 0.1284 - acc: 0.9512 - val_loss: 1.6118 - val_acc: 0.9000
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 17/30
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1941 - acc: 0.9429 - val_loss: 1.2089 - val_acc: 0.9250
# Epoch 18/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.1189 - acc: 0.9646 - val_loss: 1.2089 - val_acc: 0.9250
# Epoch 19/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.1252 - acc: 0.9539 - val_loss: 2.0148 - val_acc: 0.8750
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 20/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.1357 - acc: 0.9538 - val_loss: 1.3485 - val_acc: 0.9000
# Epoch 21/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.1002 - acc: 0.9755 - val_loss: 2.0148 - val_acc: 0.8750
# Epoch 22/30
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1038 - acc: 0.9646 - val_loss: 2.0148 - val_acc: 0.8750
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 23/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.1043 - acc: 0.9674 - val_loss: 2.1593 - val_acc: 0.8500
# Epoch 24/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.1475 - acc: 0.9483 - val_loss: 2.0148 - val_acc: 0.8750
# Epoch 25/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.1185 - acc: 0.9484 - val_loss: 2.9877 - val_acc: 0.8000
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 26/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.1075 - acc: 0.9566 - val_loss: 3.2236 - val_acc: 0.8000
# Epoch 27/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.0980 - acc: 0.9646 - val_loss: 3.1918 - val_acc: 0.8000
# Epoch 28/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.1435 - acc: 0.9510 - val_loss: 3.2236 - val_acc: 0.8000
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 29/30
# 23/22 [==============================] - 1s 56ms/step - loss: 0.1081 - acc: 0.9565 - val_loss: 3.2236 - val_acc: 0.8000
# Epoch 30/30
# 23/22 [==============================] - 1s 56ms/step - loss: 0.0924 - acc: 0.9646 - val_loss: 2.8207 - val_acc: 0.8250
# training model: 1
# Epoch 1/30
# 23/22 [==============================] - 9s 409ms/step - loss: 0.6587 - acc: 0.5950 - val_loss: 4.8586 - val_acc: 0.6750
# Epoch 2/30
# 23/22 [==============================] - 1s 38ms/step - loss: 0.4881 - acc: 0.7749 - val_loss: 2.3914 - val_acc: 0.8500
# Epoch 3/30
# 23/22 [==============================] - 1s 51ms/step - loss: 0.4230 - acc: 0.8152 - val_loss: 1.6200 - val_acc: 0.9000
# Epoch 4/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.2719 - acc: 0.8885 - val_loss: 2.8207 - val_acc: 0.8250
# Epoch 5/30
# 23/22 [==============================] - 1s 56ms/step - loss: 0.3493 - acc: 0.8508 - val_loss: 0.8059 - val_acc: 0.9500
# Epoch 6/30
# 23/22 [==============================] - 1s 56ms/step - loss: 0.2144 - acc: 0.9022 - val_loss: 0.4053 - val_acc: 0.9750
# Epoch 7/30
# 23/22 [==============================] - 1s 57ms/step - loss: 0.2144 - acc: 0.9076 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 8/30
# 23/22 [==============================] - 1s 56ms/step - loss: 0.1851 - acc: 0.9266 - val_loss: 1.2089 - val_acc: 0.9250
# Epoch 9/30
# 23/22 [==============================] - 1s 56ms/step - loss: 0.2032 - acc: 0.9294 - val_loss: 2.2542 - val_acc: 0.8500
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 10/30
# 23/22 [==============================] - 1s 38ms/step - loss: 0.1517 - acc: 0.9510 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 11/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.1793 - acc: 0.9347 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 12/30
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1554 - acc: 0.9456 - val_loss: 0.8059 - val_acc: 0.9500
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 13/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.1240 - acc: 0.9728 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 14/30
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1392 - acc: 0.9456 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 15/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.1016 - acc: 0.9701 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 16/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.0943 - acc: 0.9538 - val_loss: 0.4030 - val_acc: 0.9750
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 17/30
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1092 - acc: 0.9620 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 18/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.1150 - acc: 0.9539 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 19/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.1276 - acc: 0.9539 - val_loss: 0.0022 - val_acc: 1.0000
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 20/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.1184 - acc: 0.9646 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 21/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.0748 - acc: 0.9810 - val_loss: 0.0798 - val_acc: 0.9750
# Epoch 22/30
# 23/22 [==============================] - 1s 53ms/step - loss: 0.0724 - acc: 0.9755 - val_loss: 0.2170 - val_acc: 0.9750
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 23/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.1645 - acc: 0.9458 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 24/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.0892 - acc: 0.9646 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 25/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.1104 - acc: 0.9648 - val_loss: 1.0960e-07 - val_acc: 1.0000
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 26/30
# 23/22 [==============================] - 1s 53ms/step - loss: 0.0797 - acc: 0.9782 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 27/30
# 23/22 [==============================] - 1s 52ms/step - loss: 0.1205 - acc: 0.9619 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 28/30
# 23/22 [==============================] - 1s 52ms/step - loss: 0.1228 - acc: 0.9592 - val_loss: 1.0960e-07 - val_acc: 1.0000
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 29/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.0776 - acc: 0.9729 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 30/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.0908 - acc: 0.9782 - val_loss: 1.0960e-07 - val_acc: 1.0000
# training model: 0
# Epoch 1/20
# 23/22 [==============================] - 9s 390ms/step - loss: 1.0699 - acc: 0.5459 - val_loss: 3.0413 - val_acc: 0.8000
# Epoch 2/20
# 23/22 [==============================] - 1s 26ms/step - loss: 0.7684 - acc: 0.6440 - val_loss: 1.2045 - val_acc: 0.9250
# Epoch 3/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.4969 - acc: 0.7936 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 4/20
# 23/22 [==============================] - 1s 43ms/step - loss: 0.4187 - acc: 0.8152 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 5/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.3727 - acc: 0.8477 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 6/20
# 23/22 [==============================] - 1s 43ms/step - loss: 0.4070 - acc: 0.8289 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 7/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.3370 - acc: 0.8749 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 8/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2750 - acc: 0.8832 - val_loss: 1.9928 - val_acc: 0.8750
# Epoch 9/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.4442 - acc: 0.8124 - val_loss: 1.2089 - val_acc: 0.9250
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 10/20
# 23/22 [==============================] - 1s 28ms/step - loss: 0.3545 - acc: 0.8667 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 11/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.3412 - acc: 0.8558 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 12/20
# 23/22 [==============================] - 1s 43ms/step - loss: 0.2960 - acc: 0.8776 - val_loss: 1.0960e-07 - val_acc: 1.0000
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 13/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2319 - acc: 0.9048 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 14/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2372 - acc: 0.9022 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 15/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2694 - acc: 0.8886 - val_loss: 0.3986 - val_acc: 0.9750
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 16/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2524 - acc: 0.8969 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 17/20
# 23/22 [==============================] - 1s 43ms/step - loss: 0.2095 - acc: 0.9157 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 18/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.2288 - acc: 0.9158 - val_loss: 1.0960e-07 - val_acc: 1.0000
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 19/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2162 - acc: 0.9076 - val_loss: 0.7062 - val_acc: 0.9500
# Epoch 20/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2562 - acc: 0.9022 - val_loss: 1.0960e-07 - val_acc: 1.0000
# training model: 1
# Epoch 1/20
# 23/22 [==============================] - 9s 395ms/step - loss: 1.1731 - acc: 0.5569 - val_loss: 7.5727 - val_acc: 0.5250
# Epoch 2/20
# 23/22 [==============================] - 1s 26ms/step - loss: 0.7016 - acc: 0.6442 - val_loss: 1.1079 - val_acc: 0.9250
# Epoch 3/20
# 23/22 [==============================] - 1s 46ms/step - loss: 0.5137 - acc: 0.7499 - val_loss: 1.1957 - val_acc: 0.9250
# Epoch 4/20
# 23/22 [==============================] - 1s 43ms/step - loss: 0.4094 - acc: 0.8150 - val_loss: 3.2236 - val_acc: 0.8000
# Epoch 5/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.6063 - acc: 0.7255 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 6/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.4325 - acc: 0.8289 - val_loss: 1.6118 - val_acc: 0.9000
# Epoch 7/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.3889 - acc: 0.8234 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 8/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.3003 - acc: 0.8750 - val_loss: 0.3986 - val_acc: 0.9750
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 9/20
# 23/22 [==============================] - 1s 27ms/step - loss: 0.2642 - acc: 0.8859 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 10/20
# 23/22 [==============================] - 1s 43ms/step - loss: 0.2857 - acc: 0.8859 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 11/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.2649 - acc: 0.8830 - val_loss: 4.9803e-06 - val_acc: 1.0000
# Epoch 12/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2437 - acc: 0.8994 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 13/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2726 - acc: 0.8995 - val_loss: 0.3992 - val_acc: 0.9750
# Epoch 14/20
# 23/22 [==============================] - 1s 43ms/step - loss: 0.2971 - acc: 0.8806 - val_loss: 0.3986 - val_acc: 0.9750
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 15/20
# 23/22 [==============================] - 1s 43ms/step - loss: 0.2514 - acc: 0.8994 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 16/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2441 - acc: 0.9022 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 17/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.2345 - acc: 0.9157 - val_loss: 0.3583 - val_acc: 0.9750
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 18/20
# 23/22 [==============================] - 1s 43ms/step - loss: 0.2399 - acc: 0.8994 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 19/20
# 23/22 [==============================] - 1s 43ms/step - loss: 0.2612 - acc: 0.8994 - val_loss: 0.1266 - val_acc: 0.9750
# Epoch 20/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2266 - acc: 0.9048 - val_loss: 0.3986 - val_acc: 0.9750
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# training model: 0
# Epoch 1/20
# 23/22 [==============================] - 10s 414ms/step - loss: 0.6967 - acc: 0.4973 - val_loss: 0.5020 - val_acc: 0.7500
# Epoch 2/20
# 23/22 [==============================] - 1s 33ms/step - loss: 0.6904 - acc: 0.5679 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 3/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.6217 - acc: 0.6738 - val_loss: 1.5942 - val_acc: 0.9000
# Epoch 4/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.3645 - acc: 0.8478 - val_loss: 1.2001 - val_acc: 0.9250
# Epoch 5/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.2820 - acc: 0.8966 - val_loss: 0.5788 - val_acc: 0.9500
# Epoch 6/20
# 23/22 [==============================] - 1s 49ms/step - loss: 0.2849 - acc: 0.8886 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 7/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.2167 - acc: 0.9211 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 8/20
# 23/22 [==============================] - 1s 49ms/step - loss: 0.2135 - acc: 0.9185 - val_loss: 1.5942 - val_acc: 0.9000
# Epoch 9/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.2022 - acc: 0.9404 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 10/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.1647 - acc: 0.9456 - val_loss: 0.3986 - val_acc: 0.9750
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 11/20
# 23/22 [==============================] - 1s 33ms/step - loss: 0.1104 - acc: 0.9674 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 12/20
# 23/22 [==============================] - 1s 47ms/step - loss: 0.1392 - acc: 0.9456 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 13/20
# 23/22 [==============================] - 1s 47ms/step - loss: 0.1505 - acc: 0.9457 - val_loss: 0.3986 - val_acc: 0.9750
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 14/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.1418 - acc: 0.9402 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 15/20
# 23/22 [==============================] - 1s 47ms/step - loss: 0.1408 - acc: 0.9431 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 16/20
# 23/22 [==============================] - 1s 50ms/step - loss: 0.0896 - acc: 0.9646 - val_loss: 0.3986 - val_acc: 0.9750
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 17/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.1070 - acc: 0.9619 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 18/20
# 23/22 [==============================] - 1s 49ms/step - loss: 0.1078 - acc: 0.9646 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 19/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.1387 - acc: 0.9484 - val_loss: 0.8015 - val_acc: 0.9500
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 20/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.1186 - acc: 0.9456 - val_loss: 0.8015 - val_acc: 0.9500
# training model: 1
# Epoch 1/20
# 23/22 [==============================] - 10s 417ms/step - loss: 0.7001 - acc: 0.5596 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 2/20
# 23/22 [==============================] - 1s 34ms/step - loss: 0.6316 - acc: 0.6902 - val_loss: 1.9928 - val_acc: 0.8750
# Epoch 3/20
# 23/22 [==============================] - 1s 49ms/step - loss: 0.3996 - acc: 0.8396 - val_loss: 2.0104 - val_acc: 0.8750
# Epoch 4/20
# 23/22 [==============================] - 1s 50ms/step - loss: 0.2872 - acc: 0.8886 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 5/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.2004 - acc: 0.9266 - val_loss: 0.7697 - val_acc: 0.9500
# Epoch 6/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.1780 - acc: 0.9212 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 7/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.1624 - acc: 0.9539 - val_loss: 1.2052 - val_acc: 0.9250
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 8/20
# 23/22 [==============================] - 1s 32ms/step - loss: 0.1354 - acc: 0.9483 - val_loss: 0.8022 - val_acc: 0.9500
# Epoch 9/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.1080 - acc: 0.9538 - val_loss: 1.2089 - val_acc: 0.9250
# Epoch 10/20
# 23/22 [==============================] - 1s 49ms/step - loss: 0.1391 - acc: 0.9376 - val_loss: 0.3986 - val_acc: 0.9750
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 11/20
# 23/22 [==============================] - 1s 50ms/step - loss: 0.1163 - acc: 0.9429 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 12/20
# 23/22 [==============================] - 1s 50ms/step - loss: 0.1069 - acc: 0.9619 - val_loss: 0.8059 - val_acc: 0.9500
# Epoch 13/20
# 23/22 [==============================] - 1s 49ms/step - loss: 0.0804 - acc: 0.9728 - val_loss: 0.8059 - val_acc: 0.9500
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 14/20
# 23/22 [==============================] - 1s 50ms/step - loss: 0.1087 - acc: 0.9674 - val_loss: 0.8059 - val_acc: 0.9500
# Epoch 15/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.1094 - acc: 0.9592 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 16/20
# 23/22 [==============================] - 1s 52ms/step - loss: 0.0863 - acc: 0.9702 - val_loss: 1.2045 - val_acc: 0.9250
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 17/20
# 23/22 [==============================] - 1s 49ms/step - loss: 0.0654 - acc: 0.9728 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 18/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.0987 - acc: 0.9619 - val_loss: 0.6628 - val_acc: 0.9500
# Epoch 19/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.0967 - acc: 0.9619 - val_loss: 0.8061 - val_acc: 0.9500
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 20/20
# 23/22 [==============================] - 1s 52ms/step - loss: 0.0833 - acc: 0.9728 - val_loss: 0.9454 - val_acc: 0.9250
# training model: 2
# Epoch 1/20
# 23/22 [==============================] - 10s 432ms/step - loss: 0.7033 - acc: 0.5028 - val_loss: 4.8252 - val_acc: 0.5000
# Epoch 2/20
# 23/22 [==============================] - 1s 33ms/step - loss: 0.6883 - acc: 0.5788 - val_loss: 3.9021 - val_acc: 0.6250
# Epoch 3/20
# 23/22 [==============================] - 1s 49ms/step - loss: 0.6079 - acc: 0.6630 - val_loss: 1.5301 - val_acc: 0.9000
# Epoch 4/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.3501 - acc: 0.8506 - val_loss: 1.5713 - val_acc: 0.9000
# Epoch 5/20
# 23/22 [==============================] - 1s 52ms/step - loss: 0.1979 - acc: 0.9211 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 6/20
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1765 - acc: 0.9374 - val_loss: 1.2045 - val_acc: 0.9250
# Epoch 7/20
# 23/22 [==============================] - 1s 52ms/step - loss: 0.1671 - acc: 0.9403 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 8/20
# 23/22 [==============================] - 1s 52ms/step - loss: 0.1537 - acc: 0.9266 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 9/20
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1495 - acc: 0.9429 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 10/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.1184 - acc: 0.9429 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 11/20
# 23/22 [==============================] - 1s 49ms/step - loss: 0.2036 - acc: 0.9376 - val_loss: 1.2089 - val_acc: 0.9250
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 12/20
# 23/22 [==============================] - 1s 34ms/step - loss: 0.1582 - acc: 0.9404 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 13/20
# 23/22 [==============================] - 1s 52ms/step - loss: 0.1572 - acc: 0.9320 - val_loss: 1.2045 - val_acc: 0.9250
# Epoch 14/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.1600 - acc: 0.9539 - val_loss: 0.8015 - val_acc: 0.9500
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 15/20
# 23/22 [==============================] - 1s 49ms/step - loss: 0.1004 - acc: 0.9648 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 16/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.1017 - acc: 0.9538 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 17/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.1125 - acc: 0.9539 - val_loss: 0.3986 - val_acc: 0.9750
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 18/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.0912 - acc: 0.9565 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 19/20
# 23/22 [==============================] - 1s 52ms/step - loss: 0.0916 - acc: 0.9674 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 20/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.0740 - acc: 0.9782 - val_loss: 0.3986 - val_acc: 0.9750
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Kfold iteration 2/10
# Total images: 400 ---- Train images: 360 ---- Test images: 40
# training model 1
# training model: 0
# Epoch 1/30
# 23/22 [==============================] - 10s 451ms/step - loss: 0.7068 - acc: 0.5274 - val_loss: 0.5570 - val_acc: 0.9000
# Epoch 2/30
# 23/22 [==============================] - 1s 38ms/step - loss: 0.6569 - acc: 0.6170 - val_loss: 2.1984 - val_acc: 0.8500
# Epoch 3/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.5631 - acc: 0.7228 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 4/30
# 23/22 [==============================] - 1s 53ms/step - loss: 0.4273 - acc: 0.8126 - val_loss: 2.8207 - val_acc: 0.8250
# Epoch 5/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.3469 - acc: 0.8508 - val_loss: 0.8059 - val_acc: 0.9500
# Epoch 6/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.3491 - acc: 0.8588 - val_loss: 3.9793 - val_acc: 0.7500
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 7/30
# 23/22 [==============================] - 1s 37ms/step - loss: 0.3117 - acc: 0.8749 - val_loss: 2.0709 - val_acc: 0.8500
# Epoch 8/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.2896 - acc: 0.8780 - val_loss: 5.2384 - val_acc: 0.6750
# Epoch 9/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.2861 - acc: 0.9022 - val_loss: 0.4030 - val_acc: 0.9750
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 10/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.2591 - acc: 0.8995 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 11/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.3009 - acc: 0.8885 - val_loss: 0.8059 - val_acc: 0.9500
# Epoch 12/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.2545 - acc: 0.8994 - val_loss: 3.2236 - val_acc: 0.8000
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 13/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.2226 - acc: 0.9212 - val_loss: 1.2089 - val_acc: 0.9250
# Epoch 14/30
# 23/22 [==============================] - 1s 53ms/step - loss: 0.2207 - acc: 0.9184 - val_loss: 0.8059 - val_acc: 0.9500
# Epoch 15/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.2119 - acc: 0.9185 - val_loss: 2.9134 - val_acc: 0.8000
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 16/30
# 23/22 [==============================] - 1s 53ms/step - loss: 0.2406 - acc: 0.9212 - val_loss: 0.8061 - val_acc: 0.9500
# Epoch 17/30
# 23/22 [==============================] - 1s 53ms/step - loss: 0.2087 - acc: 0.9293 - val_loss: 0.9946 - val_acc: 0.9250
# Epoch 18/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.2337 - acc: 0.9102 - val_loss: 0.8015 - val_acc: 0.9500
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 19/30
# 23/22 [==============================] - 1s 53ms/step - loss: 0.2214 - acc: 0.9049 - val_loss: 0.8272 - val_acc: 0.9250
# Epoch 20/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.1908 - acc: 0.9347 - val_loss: 1.2089 - val_acc: 0.9250
# Epoch 21/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.1794 - acc: 0.9403 - val_loss: 0.8059 - val_acc: 0.9500
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 22/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.2695 - acc: 0.9021 - val_loss: 0.8176 - val_acc: 0.9500
# Epoch 23/30
# 23/22 [==============================] - 1s 56ms/step - loss: 0.2153 - acc: 0.9104 - val_loss: 0.8059 - val_acc: 0.9500
# Epoch 24/30
# 23/22 [==============================] - 1s 56ms/step - loss: 0.1771 - acc: 0.9293 - val_loss: 0.5681 - val_acc: 0.9500
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 25/30
# 23/22 [==============================] - 1s 58ms/step - loss: 0.1819 - acc: 0.9374 - val_loss: 0.7786 - val_acc: 0.9500
# Epoch 26/30
# 23/22 [==============================] - 1s 56ms/step - loss: 0.2092 - acc: 0.9214 - val_loss: 0.8059 - val_acc: 0.9500
# Epoch 27/30
# 23/22 [==============================] - 1s 56ms/step - loss: 0.1935 - acc: 0.9184 - val_loss: 0.8059 - val_acc: 0.9500
# Epoch 28/30
# 23/22 [==============================] - 1s 57ms/step - loss: 0.1911 - acc: 0.9430 - val_loss: 0.8059 - val_acc: 0.9500
# Epoch 29/30
# 23/22 [==============================] - 1s 56ms/step - loss: 0.2583 - acc: 0.9102 - val_loss: 0.8059 - val_acc: 0.9500
# Epoch 30/30
# 23/22 [==============================] - 1s 57ms/step - loss: 0.1979 - acc: 0.9185 - val_loss: 0.8059 - val_acc: 0.9500
# training model: 1
# Epoch 1/30
# 23/22 [==============================] - 10s 456ms/step - loss: 0.7024 - acc: 0.5299 - val_loss: 0.4280 - val_acc: 0.9000
# Epoch 2/30
# 23/22 [==============================] - 1s 37ms/step - loss: 0.6157 - acc: 0.6277 - val_loss: 0.5877 - val_acc: 0.9500
# Epoch 3/30
# 23/22 [==============================] - 1s 53ms/step - loss: 0.4300 - acc: 0.8286 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 4/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.3205 - acc: 0.8804 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 5/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.2406 - acc: 0.9075 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 6/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.2594 - acc: 0.9021 - val_loss: 0.3986 - val_acc: 0.9750
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 7/30
# 23/22 [==============================] - 1s 37ms/step - loss: 0.1825 - acc: 0.9456 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 8/30
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1795 - acc: 0.9510 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 9/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.1543 - acc: 0.9348 - val_loss: 0.7971 - val_acc: 0.9500
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 10/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.1810 - acc: 0.9266 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 11/30
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1658 - acc: 0.9347 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 12/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.1827 - acc: 0.9457 - val_loss: 0.3986 - val_acc: 0.9750
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 13/30
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1553 - acc: 0.9512 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 14/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.1515 - acc: 0.9510 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 15/30
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1708 - acc: 0.9374 - val_loss: 0.3986 - val_acc: 0.9750
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 16/30
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1370 - acc: 0.9538 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 17/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.1610 - acc: 0.9432 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 18/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.1370 - acc: 0.9456 - val_loss: 0.3986 - val_acc: 0.9750
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 19/30
# 23/22 [==============================] - 1s 54ms/step - loss: 0.1421 - acc: 0.9648 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 20/30
# 23/22 [==============================] - 1s 57ms/step - loss: 0.1433 - acc: 0.9538 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 21/30
# 23/22 [==============================] - 1s 56ms/step - loss: 0.1301 - acc: 0.9539 - val_loss: 0.3986 - val_acc: 0.9750
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 22/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.1350 - acc: 0.9402 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 23/30
# 23/22 [==============================] - 1s 56ms/step - loss: 0.1590 - acc: 0.9404 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 24/30
# 23/22 [==============================] - 1s 57ms/step - loss: 0.1635 - acc: 0.9429 - val_loss: 0.3986 - val_acc: 0.9750
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 25/30
# 23/22 [==============================] - 1s 56ms/step - loss: 0.1518 - acc: 0.9321 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 26/30
# 23/22 [==============================] - 1s 56ms/step - loss: 0.1222 - acc: 0.9646 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 27/30
# 23/22 [==============================] - 1s 56ms/step - loss: 0.1224 - acc: 0.9592 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 28/30
# 23/22 [==============================] - 1s 58ms/step - loss: 0.1516 - acc: 0.9429 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 29/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.1382 - acc: 0.9592 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 30/30
# 23/22 [==============================] - 1s 55ms/step - loss: 0.1341 - acc: 0.9484 - val_loss: 0.3986 - val_acc: 0.9750
# training model: 0
# Epoch 1/20
# 23/22 [==============================] - 10s 442ms/step - loss: 1.8699 - acc: 0.4947 - val_loss: 3.6247 - val_acc: 0.7250
# Epoch 2/20
# 23/22 [==============================] - 1s 26ms/step - loss: 0.9198 - acc: 0.5597 - val_loss: 6.0918 - val_acc: 0.6000
# Epoch 3/20
# 23/22 [==============================] - 1s 46ms/step - loss: 0.5858 - acc: 0.7040 - val_loss: 2.7899 - val_acc: 0.8250
# Epoch 4/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.4456 - acc: 0.7962 - val_loss: 6.0443 - val_acc: 0.6250
# Epoch 5/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.4305 - acc: 0.8016 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 6/20
# 23/22 [==============================] - 1s 46ms/step - loss: 0.3513 - acc: 0.8508 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 7/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.3126 - acc: 0.8668 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 8/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.4099 - acc: 0.8153 - val_loss: 0.8015 - val_acc: 0.9500
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 9/20
# 23/22 [==============================] - 1s 27ms/step - loss: 0.2594 - acc: 0.8994 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 10/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2731 - acc: 0.8942 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 11/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.3070 - acc: 0.8532 - val_loss: 1.2089 - val_acc: 0.9250
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 12/20
# 23/22 [==============================] - 1s 43ms/step - loss: 0.2360 - acc: 0.9212 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 13/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.2901 - acc: 0.8860 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 14/20
# 23/22 [==============================] - 1s 43ms/step - loss: 0.2779 - acc: 0.8751 - val_loss: 0.4030 - val_acc: 0.9750
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 15/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.1964 - acc: 0.9430 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 16/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.2483 - acc: 0.8940 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 17/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.2224 - acc: 0.9104 - val_loss: 0.4030 - val_acc: 0.9750
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 18/20
# 23/22 [==============================] - 1s 43ms/step - loss: 0.2938 - acc: 0.8913 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 19/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2708 - acc: 0.9076 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 20/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.2559 - acc: 0.8994 - val_loss: 0.4030 - val_acc: 0.9750
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# training model: 1
# Epoch 1/20
# 23/22 [==============================] - 10s 444ms/step - loss: 1.1561 - acc: 0.5762 - val_loss: 1.9928 - val_acc: 0.8750
# Epoch 2/20
# 23/22 [==============================] - 1s 27ms/step - loss: 0.9305 - acc: 0.6251 - val_loss: 4.0009 - val_acc: 0.7500
# Epoch 3/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.6045 - acc: 0.7202 - val_loss: 1.6109 - val_acc: 0.9000
# Epoch 4/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.4594 - acc: 0.7911 - val_loss: 1.1957 - val_acc: 0.9250
# Epoch 5/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.4350 - acc: 0.8344 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 6/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.3598 - acc: 0.8561 - val_loss: 4.0295 - val_acc: 0.7500
# Epoch 7/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.4867 - acc: 0.7747 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 8/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2967 - acc: 0.8722 - val_loss: 0.3986 - val_acc: 0.9750
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 9/20
# 23/22 [==============================] - 1s 28ms/step - loss: 0.2472 - acc: 0.8940 - val_loss: 1.1957 - val_acc: 0.9250
# Epoch 10/20
# 23/22 [==============================] - 1s 43ms/step - loss: 0.3303 - acc: 0.8696 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 11/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.3532 - acc: 0.8290 - val_loss: 0.4030 - val_acc: 0.9750
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 12/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2935 - acc: 0.8914 - val_loss: 1.1957 - val_acc: 0.9250
# Epoch 13/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2883 - acc: 0.8832 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 14/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2478 - acc: 0.8803 - val_loss: 0.8015 - val_acc: 0.9500
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 15/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.2518 - acc: 0.8942 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 16/20
# 23/22 [==============================] - 1s 43ms/step - loss: 0.2927 - acc: 0.8806 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 17/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.2568 - acc: 0.8886 - val_loss: 0.4030 - val_acc: 0.9750
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 18/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2413 - acc: 0.8939 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 19/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2388 - acc: 0.8916 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 20/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2271 - acc: 0.9050 - val_loss: 0.4030 - val_acc: 0.9750
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# training model: 0
# Epoch 1/20
# 23/22 [==============================] - 11s 458ms/step - loss: 0.6854 - acc: 0.5788 - val_loss: 7.4762 - val_acc: 0.5250
# Epoch 2/20
# 23/22 [==============================] - 1s 33ms/step - loss: 0.5859 - acc: 0.7092 - val_loss: 5.8626 - val_acc: 0.6000
# Epoch 3/20
# 23/22 [==============================] - 1s 50ms/step - loss: 0.3640 - acc: 0.8398 - val_loss: 1.1957 - val_acc: 0.9250
# Epoch 4/20
# 23/22 [==============================] - 1s 52ms/step - loss: 0.2474 - acc: 0.8968 - val_loss: 1.9156 - val_acc: 0.8500
# Epoch 5/20
# 23/22 [==============================] - 1s 50ms/step - loss: 0.2634 - acc: 0.8806 - val_loss: 0.8059 - val_acc: 0.9500
# Epoch 6/20
# 23/22 [==============================] - 1s 50ms/step - loss: 0.2045 - acc: 0.9266 - val_loss: 2.8207 - val_acc: 0.8250
# Epoch 7/20
# 23/22 [==============================] - 1s 50ms/step - loss: 0.2403 - acc: 0.9102 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 8/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.1750 - acc: 0.9403 - val_loss: 1.0960e-07 - val_acc: 1.0000
# Epoch 9/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.1609 - acc: 0.9510 - val_loss: 1.1008 - val_acc: 0.9250
# Epoch 10/20
# 23/22 [==============================] - 1s 49ms/step - loss: 0.1575 - acc: 0.9429 - val_loss: 0.4060 - val_acc: 0.9750
# Epoch 11/20
# 23/22 [==============================] - 1s 49ms/step - loss: 0.1458 - acc: 0.9484 - val_loss: 1.1957 - val_acc: 0.9250
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 12/20
# 23/22 [==============================] - 1s 33ms/step - loss: 0.1198 - acc: 0.9619 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 13/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.1194 - acc: 0.9565 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 14/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.1407 - acc: 0.9487 - val_loss: 0.3986 - val_acc: 0.9750
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 15/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.1127 - acc: 0.9646 - val_loss: 0.2358 - val_acc: 0.9750
# Epoch 16/20
# 23/22 [==============================] - 1s 49ms/step - loss: 0.1293 - acc: 0.9592 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 17/20
# 23/22 [==============================] - 1s 49ms/step - loss: 0.1011 - acc: 0.9620 - val_loss: 0.7971 - val_acc: 0.9500
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 18/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.0794 - acc: 0.9646 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 19/20
# 23/22 [==============================] - 1s 47ms/step - loss: 0.0994 - acc: 0.9592 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 20/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.0952 - acc: 0.9728 - val_loss: 0.3986 - val_acc: 0.9750
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# training model: 1
# Epoch 1/20
# 23/22 [==============================] - 11s 464ms/step - loss: 0.7040 - acc: 0.4998 - val_loss: 3.4742 - val_acc: 0.5000
# Epoch 2/20
# 23/22 [==============================] - 1s 32ms/step - loss: 0.6310 - acc: 0.6276 - val_loss: 3.5870 - val_acc: 0.7750
# Epoch 3/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.3847 - acc: 0.8150 - val_loss: 0.1514 - val_acc: 0.9750
# Epoch 4/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.3911 - acc: 0.8615 - val_loss: 1.9928 - val_acc: 0.8750
# Epoch 5/20
# 23/22 [==============================] - 1s 49ms/step - loss: 0.2767 - acc: 0.8994 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 6/20
# 23/22 [==============================] - 1s 49ms/step - loss: 0.2464 - acc: 0.8968 - val_loss: 1.5942 - val_acc: 0.9000
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 7/20
# 23/22 [==============================] - 1s 33ms/step - loss: 0.2220 - acc: 0.9130 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 8/20
# 23/22 [==============================] - 1s 47ms/step - loss: 0.1684 - acc: 0.9241 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 9/20
# 23/22 [==============================] - 1s 49ms/step - loss: 0.1628 - acc: 0.9374 - val_loss: 0.7971 - val_acc: 0.9500
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 10/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.1721 - acc: 0.9350 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 11/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.1492 - acc: 0.9430 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 12/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.1461 - acc: 0.9429 - val_loss: 0.7971 - val_acc: 0.9500
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 13/20
# 23/22 [==============================] - 1s 49ms/step - loss: 0.1374 - acc: 0.9430 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 14/20
# 23/22 [==============================] - 1s 47ms/step - loss: 0.1312 - acc: 0.9430 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 15/20
# 23/22 [==============================] - 1s 49ms/step - loss: 0.1486 - acc: 0.9510 - val_loss: 0.7971 - val_acc: 0.9500
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 16/20
# 23/22 [==============================] - 1s 50ms/step - loss: 0.1650 - acc: 0.9294 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 17/20
# 23/22 [==============================] - 1s 52ms/step - loss: 0.1373 - acc: 0.9510 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 18/20
# 23/22 [==============================] - 1s 50ms/step - loss: 0.1420 - acc: 0.9483 - val_loss: 0.7971 - val_acc: 0.9500
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 19/20
# 23/22 [==============================] - 1s 50ms/step - loss: 0.1170 - acc: 0.9648 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 20/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.1182 - acc: 0.9648 - val_loss: 0.7971 - val_acc: 0.9500
# training model: 2
# Epoch 1/20
# 23/22 [==============================] - 11s 472ms/step - loss: 0.7076 - acc: 0.5083 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 2/20
# 23/22 [==============================] - 1s 32ms/step - loss: 0.6723 - acc: 0.6197 - val_loss: 3.1885 - val_acc: 0.8000
# Epoch 3/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.4730 - acc: 0.7960 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 4/20
# 23/22 [==============================] - 1s 46ms/step - loss: 0.2389 - acc: 0.9021 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 5/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.2214 - acc: 0.9105 - val_loss: 1.5942 - val_acc: 0.9000
# Epoch 6/20
# 23/22 [==============================] - 1s 47ms/step - loss: 0.1612 - acc: 0.9348 - val_loss: 0.7971 - val_acc: 0.9500
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 7/20
# 23/22 [==============================] - 1s 32ms/step - loss: 0.2116 - acc: 0.9214 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 8/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.1674 - acc: 0.9348 - val_loss: 0.6111 - val_acc: 0.9500
# Epoch 9/20
# 23/22 [==============================] - 1s 47ms/step - loss: 0.1422 - acc: 0.9374 - val_loss: 0.7971 - val_acc: 0.9500
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 10/20
# 23/22 [==============================] - 1s 50ms/step - loss: 0.1362 - acc: 0.9456 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 11/20
# 23/22 [==============================] - 1s 47ms/step - loss: 0.1218 - acc: 0.9430 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 12/20
# 23/22 [==============================] - 1s 48ms/step - loss: 0.1155 - acc: 0.9619 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 13/20
# 23/22 [==============================] - 1s 49ms/step - loss: 0.1173 - acc: 0.9592 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 14/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.1028 - acc: 0.9648 - val_loss: 0.3986 - val_acc: 0.9750
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 15/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.1170 - acc: 0.9483 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 16/20
# 23/22 [==============================] - 1s 47ms/step - loss: 0.0832 - acc: 0.9701 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 17/20
# 23/22 [==============================] - 1s 49ms/step - loss: 0.0864 - acc: 0.9728 - val_loss: 0.3986 - val_acc: 0.9750
#
# ...
# Epoch 26/30
# 23/22 [==============================] - 1s 59ms/step - loss: 0.1572 - acc: 0.9430 - val_loss: 1.2001 - val_acc: 0.9250
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 27/30
# 23/22 [==============================] - 1s 57ms/step - loss: 0.1533 - acc: 0.9429 - val_loss: 1.2001 - val_acc: 0.9250
# Epoch 28/30
# 23/22 [==============================] - 1s 57ms/step - loss: 0.1570 - acc: 0.9377 - val_loss: 1.2001 - val_acc: 0.9250
# Epoch 29/30
# 23/22 [==============================] - 1s 57ms/step - loss: 0.1533 - acc: 0.9483 - val_loss: 1.2001 - val_acc: 0.9250
# Epoch 30/30
# 23/22 [==============================] - 1s 56ms/step - loss: 0.1346 - acc: 0.9565 - val_loss: 1.2001 - val_acc: 0.9250
# training model: 0
# Epoch 1/20
# 23/22 [==============================] - 19s 824ms/step - loss: 1.0018 - acc: 0.5218 - val_loss: 4.7249 - val_acc: 0.7000
# Epoch 2/20
# 23/22 [==============================] - 1s 28ms/step - loss: 0.6535 - acc: 0.6820 - val_loss: 2.8031 - val_acc: 0.8250
# Epoch 3/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.4709 - acc: 0.7798 - val_loss: 1.5950 - val_acc: 0.9000
# Epoch 4/20
# 23/22 [==============================] - 1s 46ms/step - loss: 0.4462 - acc: 0.7826 - val_loss: 1.9972 - val_acc: 0.8750
# Epoch 5/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.4029 - acc: 0.8042 - val_loss: 2.0848 - val_acc: 0.8500
# Epoch 6/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.3453 - acc: 0.8481 - val_loss: 2.0016 - val_acc: 0.8750
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 7/20
# 23/22 [==============================] - 1s 29ms/step - loss: 0.2966 - acc: 0.8614 - val_loss: 1.5942 - val_acc: 0.9000
# Epoch 8/20
# 23/22 [==============================] - 1s 46ms/step - loss: 0.2967 - acc: 0.8806 - val_loss: 1.5986 - val_acc: 0.9000
# Epoch 9/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.3173 - acc: 0.8670 - val_loss: 1.5986 - val_acc: 0.9000
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 10/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.2921 - acc: 0.8858 - val_loss: 1.5986 - val_acc: 0.9000
# Epoch 11/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.2261 - acc: 0.9130 - val_loss: 1.3187 - val_acc: 0.8750
# Epoch 12/20
# 23/22 [==============================] - 1s 46ms/step - loss: 0.3012 - acc: 0.8804 - val_loss: 1.5986 - val_acc: 0.9000
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 13/20
# 23/22 [==============================] - 1s 46ms/step - loss: 0.2501 - acc: 0.9022 - val_loss: 1.5986 - val_acc: 0.9000
# Epoch 14/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2399 - acc: 0.9102 - val_loss: 1.5986 - val_acc: 0.9000
# Epoch 15/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.2359 - acc: 0.9238 - val_loss: 1.5986 - val_acc: 0.9000
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 16/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.2214 - acc: 0.9184 - val_loss: 1.9972 - val_acc: 0.8750
# Epoch 17/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.2516 - acc: 0.9021 - val_loss: 1.5986 - val_acc: 0.9000
# Epoch 18/20
# 23/22 [==============================] - 1s 46ms/step - loss: 0.2562 - acc: 0.9104 - val_loss: 1.5986 - val_acc: 0.9000
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 19/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.2276 - acc: 0.9130 - val_loss: 1.5986 - val_acc: 0.9000
# Epoch 20/20
# 23/22 [==============================] - 1s 46ms/step - loss: 0.2177 - acc: 0.9185 - val_loss: 1.5986 - val_acc: 0.9000
# training model: 1
# Epoch 1/20
# 23/22 [==============================] - 19s 828ms/step - loss: 0.9757 - acc: 0.5030 - val_loss: 2.9763 - val_acc: 0.8000
# Epoch 2/20
# 23/22 [==============================] - 1s 29ms/step - loss: 0.6675 - acc: 0.6521 - val_loss: 2.8031 - val_acc: 0.8250
# Epoch 3/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.4531 - acc: 0.8179 - val_loss: 2.0302 - val_acc: 0.8500
# Epoch 4/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.3980 - acc: 0.8179 - val_loss: 1.9972 - val_acc: 0.8750
# Epoch 5/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.4945 - acc: 0.8044 - val_loss: 2.0060 - val_acc: 0.8750
# Epoch 6/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.4321 - acc: 0.8317 - val_loss: 1.9928 - val_acc: 0.8750
# Epoch 7/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.4648 - acc: 0.8070 - val_loss: 1.9972 - val_acc: 0.8750
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 8/20
# 23/22 [==============================] - 1s 28ms/step - loss: 0.3017 - acc: 0.8803 - val_loss: 1.5942 - val_acc: 0.9000
# Epoch 9/20
# 23/22 [==============================] - 1s 46ms/step - loss: 0.3396 - acc: 0.8776 - val_loss: 1.6006 - val_acc: 0.9000
# Epoch 10/20
# 23/22 [==============================] - 1s 46ms/step - loss: 0.2695 - acc: 0.8830 - val_loss: 2.0060 - val_acc: 0.8750
# Epoch 11/20
# 23/22 [==============================] - 1s 47ms/step - loss: 0.3456 - acc: 0.8586 - val_loss: 1.9972 - val_acc: 0.8750
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 12/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2755 - acc: 0.8966 - val_loss: 1.5942 - val_acc: 0.9000
# Epoch 13/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.2013 - acc: 0.9267 - val_loss: 1.9972 - val_acc: 0.8750
# Epoch 14/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.2439 - acc: 0.9157 - val_loss: 1.5986 - val_acc: 0.9000
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 15/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2143 - acc: 0.9185 - val_loss: 1.5986 - val_acc: 0.9000
# Epoch 16/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.2412 - acc: 0.9022 - val_loss: 1.9972 - val_acc: 0.8750
# Epoch 17/20
# 23/22 [==============================] - 1s 44ms/step - loss: 0.2061 - acc: 0.9157 - val_loss: 1.9972 - val_acc: 0.8750
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 18/20
# 23/22 [==============================] - 1s 46ms/step - loss: 0.2450 - acc: 0.8861 - val_loss: 1.9972 - val_acc: 0.8750
# Epoch 19/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.2086 - acc: 0.9157 - val_loss: 1.5986 - val_acc: 0.9000
# Epoch 20/20
# 23/22 [==============================] - 1s 45ms/step - loss: 0.2667 - acc: 0.9075 - val_loss: 1.5986 - val_acc: 0.9000
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# training model: 0
# Epoch 1/20
# 23/22 [==============================] - 19s 842ms/step - loss: 0.6959 - acc: 0.5788 - val_loss: 0.6396 - val_acc: 0.9500
# Epoch 2/20
# 23/22 [==============================] - 1s 35ms/step - loss: 0.4469 - acc: 0.8098 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 3/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.2357 - acc: 0.9049 - val_loss: 0.3986 - val_acc: 0.9750
# Epoch 4/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.2293 - acc: 0.9102 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 5/20
# 23/22 [==============================] - 1s 53ms/step - loss: 0.2063 - acc: 0.9131 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 6/20
# 23/22 [==============================] - 1s 52ms/step - loss: 0.1543 - acc: 0.9538 - val_loss: 0.7971 - val_acc: 0.9500
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 7/20
# 23/22 [==============================] - 1s 35ms/step - loss: 0.1641 - acc: 0.9240 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 8/20
# 23/22 [==============================] - 1s 54ms/step - loss: 0.1546 - acc: 0.9374 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 9/20
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1236 - acc: 0.9565 - val_loss: 0.8015 - val_acc: 0.9500
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 10/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.0939 - acc: 0.9619 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 11/20
# 23/22 [==============================] - 1s 54ms/step - loss: 0.1293 - acc: 0.9484 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 12/20
# 23/22 [==============================] - 1s 52ms/step - loss: 0.1296 - acc: 0.9565 - val_loss: 0.8015 - val_acc: 0.9500
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 13/20
# 23/22 [==============================] - 1s 52ms/step - loss: 0.0994 - acc: 0.9646 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 14/20
# 23/22 [==============================] - 1s 53ms/step - loss: 0.0911 - acc: 0.9701 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 15/20
# 23/22 [==============================] - 1s 54ms/step - loss: 0.0843 - acc: 0.9619 - val_loss: 0.8015 - val_acc: 0.9500
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 16/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.1034 - acc: 0.9593 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 17/20
# 23/22 [==============================] - 1s 50ms/step - loss: 0.0715 - acc: 0.9755 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 18/20
# 23/22 [==============================] - 1s 50ms/step - loss: 0.1213 - acc: 0.9539 - val_loss: 0.8015 - val_acc: 0.9500
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 19/20
# 23/22 [==============================] - 1s 52ms/step - loss: 0.0882 - acc: 0.9674 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 20/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.0941 - acc: 0.9674 - val_loss: 0.8015 - val_acc: 0.9500
# training model: 1
# Epoch 1/20
# 23/22 [==============================] - 20s 856ms/step - loss: 0.7016 - acc: 0.5298 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 2/20
# 23/22 [==============================] - 1s 35ms/step - loss: 0.6641 - acc: 0.5732 - val_loss: 6.3770 - val_acc: 0.6000
# Epoch 3/20
# 23/22 [==============================] - 1s 49ms/step - loss: 0.4062 - acc: 0.8178 - val_loss: 1.5986 - val_acc: 0.9000
# Epoch 4/20
# 23/22 [==============================] - 1s 53ms/step - loss: 0.2939 - acc: 0.8994 - val_loss: 1.1996 - val_acc: 0.9250
# Epoch 5/20
# 23/22 [==============================] - 1s 50ms/step - loss: 0.2274 - acc: 0.9184 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 6/20
# 23/22 [==============================] - 1s 53ms/step - loss: 0.2518 - acc: 0.8940 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 7/20
# 23/22 [==============================] - 1s 52ms/step - loss: 0.2490 - acc: 0.9078 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 8/20
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1828 - acc: 0.9238 - val_loss: 1.2001 - val_acc: 0.9250
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 9/20
# 23/22 [==============================] - 1s 36ms/step - loss: 0.1729 - acc: 0.9429 - val_loss: 1.2001 - val_acc: 0.9250
# Epoch 10/20
# 23/22 [==============================] - 1s 52ms/step - loss: 0.1750 - acc: 0.9347 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 11/20
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1332 - acc: 0.9539 - val_loss: 1.2001 - val_acc: 0.9250
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 12/20
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1394 - acc: 0.9619 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 13/20
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1072 - acc: 0.9646 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 14/20
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1310 - acc: 0.9484 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 15/20
# 23/22 [==============================] - 1s 52ms/step - loss: 0.1160 - acc: 0.9619 - val_loss: 0.4030 - val_acc: 0.9750
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 16/20
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1035 - acc: 0.9512 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 17/20
# 23/22 [==============================] - 1s 52ms/step - loss: 0.1257 - acc: 0.9510 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 18/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.0976 - acc: 0.9649 - val_loss: 0.8015 - val_acc: 0.9500
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 19/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.0879 - acc: 0.9674 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 20/20
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1073 - acc: 0.9565 - val_loss: 0.4030 - val_acc: 0.9750
# training model: 2
# Epoch 1/20
# 23/22 [==============================] - 20s 867ms/step - loss: 0.6973 - acc: 0.5679 - val_loss: 5.5339 - val_acc: 0.5500
# Epoch 2/20
# 23/22 [==============================] - 1s 36ms/step - loss: 0.5409 - acc: 0.6877 - val_loss: 0.7971 - val_acc: 0.9500
# Epoch 3/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.2953 - acc: 0.8887 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 4/20
# 23/22 [==============================] - 1s 54ms/step - loss: 0.2103 - acc: 0.9078 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 5/20
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1839 - acc: 0.9374 - val_loss: 1.2001 - val_acc: 0.9250
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 6/20
# 23/22 [==============================] - 1s 34ms/step - loss: 0.1854 - acc: 0.9348 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 7/20
# 23/22 [==============================] - 1s 50ms/step - loss: 0.1813 - acc: 0.9403 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 8/20
# 23/22 [==============================] - 1s 52ms/step - loss: 0.1411 - acc: 0.9430 - val_loss: 0.8015 - val_acc: 0.9500
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 9/20
# 23/22 [==============================] - 1s 50ms/step - loss: 0.1338 - acc: 0.9539 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 10/20
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1196 - acc: 0.9593 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 11/20
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1288 - acc: 0.9430 - val_loss: 0.8015 - val_acc: 0.9500
# Epoch 12/20
# 23/22 [==============================] - 1s 52ms/step - loss: 0.1106 - acc: 0.9592 - val_loss: 0.8015 - val_acc: 0.9500
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 13/20
# 23/22 [==============================] - 1s 53ms/step - loss: 0.0983 - acc: 0.9646 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 14/20
# 23/22 [==============================] - 1s 53ms/step - loss: 0.0890 - acc: 0.9646 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 15/20
# 23/22 [==============================] - 1s 53ms/step - loss: 0.0958 - acc: 0.9592 - val_loss: 0.4030 - val_acc: 0.9750
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 16/20
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1375 - acc: 0.9513 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 17/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.1034 - acc: 0.9648 - val_loss: 0.4033 - val_acc: 0.9750
# Epoch 18/20
# 23/22 [==============================] - 1s 51ms/step - loss: 0.0889 - acc: 0.9728 - val_loss: 0.4030 - val_acc: 0.9750
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 19/20
# 23/22 [==============================] - 1s 50ms/step - loss: 0.0890 - acc: 0.9675 - val_loss: 0.4030 - val_acc: 0.9750
# Epoch 20/20
# 23/22 [==============================] - 1s 53ms/step - loss: 0.1056 - acc: 0.9484 - val_loss: 0.4030 - val_acc: 0.9750

# %%
# We loop over all reports (1 per fold) and then compute the average of all weighted f1 scores
final_f1_score = np.mean([rep['weighted avg']['f1-score'] for rep in reports])

print('Final F1-Score is: {}%'.format(np.round(final_f1_score*100,2)))
# Out:
# Final F1-Score is: 97.25%
