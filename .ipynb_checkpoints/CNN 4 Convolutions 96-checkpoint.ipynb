# %% [markdown]
# # TO USE GPU
#
# USE GOOGLE COLLAB AND MOUNT YOUR DRIVE BY UNCOMMENTING THE FOLLOWING CODE (Ensure image folder is in your google drive)
#
# Also, to enable the GPU on google colab, go to runtime tab and change runtime and add accelerator GPU

# %%
## Mount google drive
#from google.colab import drive
#drive.mount("/content/gdrive")

# %% [markdown]
# # Convolution Neural Network - CNN Baseline
#
# Convolution Neural Networks or CNN or Convnets are the current state of the art for most computer vision tasks.
#
# This notebook will aply k-fold and use the concept of transfer learning.
#
# Transfer learning:
# - Train a CNN using 6 emotions dataset known as FER2013 dataset
# - Strip out the top layers of that trained CNN architecture
# - Freeze the weights of that architecture in hopes it learned high level features already
# - Add back other layers that are trainable
# - Train using our Smile dataset to learn specific features

# %%
# Import libraries and ignore warnings
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
np.random.seed(2)

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# Plot architecture
import keras
import pydot
from keras.utils.vis_utils import model_to_dot

from keras import models
from keras import layers
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.preprocessing import image

import os
from PIL import Image
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Data
#
# The first step is to import images and store their **pixel** values in a dataframe. This will allow us to create 10 fold by using the index of the rows.
#
# We will also **shuffle** the dataframe because the first 200 images are smilling and next 200 images are neutral.

# %%
# Read the annotations file that contains the label and the image file name
labels = pd.read_csv('./SMILE_Dataset/annotations.csv', header=None, names=['fname','label'])

# Shuffle data
labels = labels.sample(frac=1).reset_index()

# Use a list comprehension to loop over image file names and import one by one and store pixel values
x = np.array([image.img_to_array(image.load_img('./SMILE_Dataset/all/'+fname, target_size=(64, 64))) for fname in labels['fname']])

# Because the names are strings, the neural network only takes in numerical formats so we will one-hot encode the label
label_encoder = LabelEncoder()
integer_encoded = label_encoder.fit_transform(labels['label'])
y = integer_encoded

# %% [markdown]
# Now we have two variables.
#
# x: all of the values for our images
# y: all of the labels (0:1)
#
# Now we have finished working with the data. Let's define an architecture for our CNN.

# %% [markdown]
# # Models

# %%
def pizza_model():
    
    model = models.Sequential()
    
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)))
    model.add(layers.MaxPooling2D((2, 2)))
    
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    
    model.add(layers.Conv2D(70, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))

    # Feed to a densily connected layer for prediction
    model.add(layers.Flatten())
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    
    # Compile model
    model.compile(loss='binary_crossentropy',
                  optimizer=optimizers.Adam(lr=0.001),
                  metrics=['acc'])
    
    return model

# %% [markdown]
# # K-Fold

# %%
# All classification reports will be added here. When we are done we can average the f1 scores
reports = []

# Apply stratified K-fold ith 10 splits. Stratified means the same distribution of classes than the whole dataset
# In this case, 50-50
kf = StratifiedKFold(n_splits=10)

# Just for printing purposes
id = 1

for train_index, test_index in kf.split(x,y):
    print('Kfold iteration {}/10'.format(id))
    print('Total images: {} ---- Train images: {} ---- Test images: {}'.format(len(x),len(train_index),len(test_index)))

    id += 1 
    
    X_train, X_test = x[train_index], x[test_index]
    y_train, y_test = y[train_index], y[test_index]
        
    model = pizza_model()
    
    datagen = ImageDataGenerator(rescale=1./255,
                                 rotation_range=10, # randomly rotate images in the range (degrees, 0 to 180)
                                 width_shift_range=0.1, # randomly shift images horizontally (fraction of total width)
                                 height_shift_range=0.1, 
                                 shear_range=0.1,
                                 zoom_range=0.1)   
    
    datagen.fit(X_train)

    # Secret sauce to get 3-5 % accuracy more
    # Adjust the learning rate over time. (Like we saw in class!)
    # The learning rate determines the size of the steps taken during the gradient descent process.
    
    learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', 
                                            patience=3, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)
    
    # Used to prevent overfitting. 
    # es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
    
    history = model.fit_generator(datagen.flow(X_train, y_train, batch_size = 20), epochs = 20, 
                              validation_data = (X_test,y_test), steps_per_epoch=len(X_train) / 20,
                              callbacks=[learning_rate_reduction])

    
    y_pred = model.predict(X_test)
    y_pred = [np.round(p[0]) for p in y_pred]
    
    print(classification_report(y_test, y_pred))
    reports.append(classification_report(y_test, y_pred,output_dict=True))
    
#     if id == 3:
#         break
# Out:
# Kfold iteration 1/10
# Total images: 400 ---- Train images: 360 ---- Test images: 40
# Epoch 1/20
# 18/18 [==============================] - 4s 220ms/step - loss: 0.6950 - acc: 0.5306 - val_loss: 0.7912 - val_acc: 0.9000
# Epoch 2/20
# 18/18 [==============================] - 3s 163ms/step - loss: 0.6342 - acc: 0.6806 - val_loss: 12.8143 - val_acc: 0.8250
# Epoch 3/20
# 18/18 [==============================] - 4s 195ms/step - loss: 0.5684 - acc: 0.6778 - val_loss: 25.2818 - val_acc: 0.8250
# Epoch 4/20
# 18/18 [==============================] - 4s 213ms/step - loss: 0.3904 - acc: 0.8417 - val_loss: 16.7153 - val_acc: 0.9500
# Epoch 5/20
# 18/18 [==============================] - 4s 198ms/step - loss: 0.2551 - acc: 0.8889 - val_loss: 11.4652 - val_acc: 0.9250
# Epoch 6/20
# 18/18 [==============================] - 3s 188ms/step - loss: 0.2135 - acc: 0.9278 - val_loss: 16.6521 - val_acc: 0.9250
# Epoch 7/20
# 18/18 [==============================] - 3s 188ms/step - loss: 0.1658 - acc: 0.9361 - val_loss: 34.2032 - val_acc: 0.9250
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 8/20
# 18/18 [==============================] - 3s 176ms/step - loss: 0.1306 - acc: 0.9444 - val_loss: 23.4700 - val_acc: 0.9250
# Epoch 9/20
# 18/18 [==============================] - 3s 192ms/step - loss: 0.1275 - acc: 0.9500 - val_loss: 22.3413 - val_acc: 0.9500
# Epoch 10/20
# 18/18 [==============================] - 4s 195ms/step - loss: 0.1080 - acc: 0.9472 - val_loss: 24.1665 - val_acc: 0.9500
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 11/20
# 18/18 [==============================] - 3s 190ms/step - loss: 0.1101 - acc: 0.9639 - val_loss: 20.9198 - val_acc: 0.9500
# Epoch 12/20
# 18/18 [==============================] - 4s 198ms/step - loss: 0.1100 - acc: 0.9583 - val_loss: 25.7083 - val_acc: 0.9500
# Epoch 13/20
# 18/18 [==============================] - 3s 188ms/step - loss: 0.1004 - acc: 0.9583 - val_loss: 24.7478 - val_acc: 0.9500
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 14/20
# 18/18 [==============================] - 3s 185ms/step - loss: 0.1059 - acc: 0.9583 - val_loss: 30.2793 - val_acc: 0.9250
# Epoch 15/20
# 18/18 [==============================] - 4s 196ms/step - loss: 0.0821 - acc: 0.9611 - val_loss: 25.3544 - val_acc: 0.9500
# Epoch 16/20
# 18/18 [==============================] - 3s 184ms/step - loss: 0.1102 - acc: 0.9611 - val_loss: 24.9767 - val_acc: 0.9500
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 17/20
# 18/18 [==============================] - 3s 185ms/step - loss: 0.1143 - acc: 0.9472 - val_loss: 25.8701 - val_acc: 0.9500
# Epoch 18/20
# 18/18 [==============================] - 3s 182ms/step - loss: 0.0937 - acc: 0.9639 - val_loss: 26.8404 - val_acc: 0.9500
# Epoch 19/20
# 18/18 [==============================] - 3s 187ms/step - loss: 0.0925 - acc: 0.9667 - val_loss: 26.0757 - val_acc: 0.9500
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 20/20
# 18/18 [==============================] - 3s 188ms/step - loss: 0.0872 - acc: 0.9667 - val_loss: 25.6637 - val_acc: 0.9500
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        20
#            1       0.95      0.95      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# Kfold iteration 2/10
# Total images: 400 ---- Train images: 360 ---- Test images: 40
# Epoch 1/20
# 18/18 [==============================] - 4s 237ms/step - loss: 0.6878 - acc: 0.5361 - val_loss: 16.9370 - val_acc: 0.5250
# Epoch 2/20
# 18/18 [==============================] - 3s 175ms/step - loss: 0.6016 - acc: 0.6750 - val_loss: 5.1444 - val_acc: 0.9000
# 18/18 [==============================] - 3s 169ms/step - loss: 0.0844 - acc: 0.9611 - val_loss: 55.1610 - val_acc: 0.8250
# Epoch 18/20
# 18/18 [==============================] - 3s 171ms/step - loss: 0.0865 - acc: 0.9778 - val_loss: 57.4035 - val_acc: 0.8500
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 19/20
# 18/18 [==============================] - 3s 171ms/step - loss: 0.0769 - acc: 0.9667 - val_loss: 58.6054 - val_acc: 0.8500
# Epoch 20/20
# 18/18 [==============================] - 3s 170ms/step - loss: 0.0828 - acc: 0.9722 - val_loss: 59.7273 - val_acc: 0.8750
#               precision    recall  f1-score   support
#
#            0       0.83      0.95      0.88        20
#            1       0.94      0.80      0.86        20
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.87        40
#
# Kfold iteration 4/10
# Total images: 400 ---- Train images: 360 ---- Test images: 40
# Epoch 1/20
# 18/18 [==============================] - 4s 225ms/step - loss: 0.6876 - acc: 0.5694 - val_loss: 12.4576 - val_acc: 0.5500
# Epoch 2/20
# 18/18 [==============================] - 3s 166ms/step - loss: 0.6342 - acc: 0.6611 - val_loss: 7.0721e-09 - val_acc: 1.0000
# Epoch 3/20
# 18/18 [==============================] - 3s 186ms/step - loss: 0.3328 - acc: 0.8611 - val_loss: 3.8735 - val_acc: 0.9750
# Epoch 4/20
# 18/18 [==============================] - 3s 172ms/step - loss: 0.2276 - acc: 0.9000 - val_loss: 1.2197e-34 - val_acc: 1.0000
# Epoch 5/20
# 18/18 [==============================] - 3s 173ms/step - loss: 0.2310 - acc: 0.9000 - val_loss: 0.4634 - val_acc: 0.9750
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 6/20
# 18/18 [==============================] - 3s 164ms/step - loss: 0.1893 - acc: 0.9333 - val_loss: 0.0000e+00 - val_acc: 1.0000
# Epoch 7/20
# 18/18 [==============================] - 3s 191ms/step - loss: 0.1739 - acc: 0.9306 - val_loss: 0.0000e+00 - val_acc: 1.0000
# Epoch 8/20
# 18/18 [==============================] - 3s 169ms/step - loss: 0.1596 - acc: 0.9333 - val_loss: 1.2003 - val_acc: 0.9750
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 9/20
# 18/18 [==============================] - 3s 169ms/step - loss: 0.1584 - acc: 0.9444 - val_loss: 1.2691e-15 - val_acc: 1.0000
# Epoch 10/20
# 18/18 [==============================] - 3s 167ms/step - loss: 0.1643 - acc: 0.9389 - val_loss: 0.1481 - val_acc: 0.9750
# Epoch 11/20
# 18/18 [==============================] - 3s 168ms/step - loss: 0.1372 - acc: 0.9417 - val_loss: 2.4165e-16 - val_acc: 1.0000
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 12/20
# 18/18 [==============================] - 3s 173ms/step - loss: 0.1312 - acc: 0.9528 - val_loss: 0.0000e+00 - val_acc: 1.0000
# Epoch 13/20
# 18/18 [==============================] - 3s 179ms/step - loss: 0.1370 - acc: 0.9333 - val_loss: 3.7924 - val_acc: 0.9750
# Epoch 14/20
# 18/18 [==============================] - 3s 169ms/step - loss: 0.1173 - acc: 0.9639 - val_loss: 0.0000e+00 - val_acc: 1.0000
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 15/20
# 18/18 [==============================] - 3s 175ms/step - loss: 0.1203 - acc: 0.9556 - val_loss: 0.0000e+00 - val_acc: 1.0000
# Epoch 16/20
# 18/18 [==============================] - 3s 173ms/step - loss: 0.1292 - acc: 0.9528 - val_loss: 4.0895e-24 - val_acc: 1.0000
# Epoch 17/20
# 18/18 [==============================] - 4s 195ms/step - loss: 0.1099 - acc: 0.9639 - val_loss: 0.0000e+00 - val_acc: 1.0000
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 18/20
# 18/18 [==============================] - 3s 176ms/step - loss: 0.1281 - acc: 0.9472 - val_loss: 0.0000e+00 - val_acc: 1.0000
# Epoch 19/20
# 18/18 [==============================] - 3s 175ms/step - loss: 0.1183 - acc: 0.9556 - val_loss: 0.0146 - val_acc: 1.0000
# Epoch 20/20
# 18/18 [==============================] - 3s 174ms/step - loss: 0.1162 - acc: 0.9472 - val_loss: 1.2631e-33 - val_acc: 1.0000
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        20
#
#     accuracy                           1.00        40
#    macro avg       1.00      1.00      1.00        40
# weighted avg       1.00      1.00      1.00        40
#
# Kfold iteration 5/10
# Total images: 400 ---- Train images: 360 ---- Test images: 40
# Epoch 1/20
# 18/18 [==============================] - 4s 231ms/step - loss: 0.7029 - acc: 0.4972 - val_loss: 3.6023 - val_acc: 0.5000
# Epoch 2/20
# 18/18 [==============================] - 3s 181ms/step - loss: 0.6485 - acc: 0.6444 - val_loss: 3.7716 - val_acc: 0.9500
# Epoch 3/20
# 18/18 [==============================] - 3s 192ms/step - loss: 0.4242 - acc: 0.8250 - val_loss: 14.6974 - val_acc: 0.9750
# Epoch 4/20
# 18/18 [==============================] - 4s 196ms/step - loss: 0.3586 - acc: 0.8444 - val_loss: 7.5951 - val_acc: 0.9750
# Epoch 5/20
# 18/18 [==============================] - 3s 173ms/step - loss: 0.2674 - acc: 0.8806 - val_loss: 32.5588 - val_acc: 0.8000
# Epoch 6/20
# 18/18 [==============================] - 3s 171ms/step - loss: 0.2792 - acc: 0.8778 - val_loss: 5.8099 - val_acc: 0.9750
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 7/20
# 18/18 [==============================] - 3s 169ms/step - loss: 0.1815 - acc: 0.9278 - val_loss: 0.0000e+00 - val_acc: 1.0000
# Epoch 8/20
# 18/18 [==============================] - 3s 173ms/step - loss: 0.1571 - acc: 0.9306 - val_loss: 3.2959 - val_acc: 0.9750
# Epoch 9/20
# 18/18 [==============================] - 3s 177ms/step - loss: 0.1624 - acc: 0.9333 - val_loss: 7.2490 - val_acc: 0.9750
# Epoch 10/20
# 18/18 [==============================] - 3s 183ms/step - loss: 0.1488 - acc: 0.9417 - val_loss: 4.0932 - val_acc: 0.9750
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 11/20
# 18/18 [==============================] - 3s 173ms/step - loss: 0.1275 - acc: 0.9444 - val_loss: 0.0000e+00 - val_acc: 1.0000
# Epoch 12/20
# 18/18 [==============================] - 3s 177ms/step - loss: 0.1308 - acc: 0.9528 - val_loss: 0.0000e+00 - val_acc: 1.0000
# Epoch 13/20
# 18/18 [==============================] - 3s 173ms/step - loss: 0.1478 - acc: 0.9389 - val_loss: 0.0000e+00 - val_acc: 1.0000
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 14/20
# 18/18 [==============================] - 3s 172ms/step - loss: 0.1230 - acc: 0.9528 - val_loss: 0.0000e+00 - val_acc: 1.0000
# Epoch 15/20
# 18/18 [==============================] - 3s 174ms/step - loss: 0.1209 - acc: 0.9611 - val_loss: 0.0000e+00 - val_acc: 1.0000
# Epoch 16/20
# 18/18 [==============================] - 3s 174ms/step - loss: 0.1465 - acc: 0.9417 - val_loss: 0.0000e+00 - val_acc: 1.0000
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 17/20
# 18/18 [==============================] - 3s 174ms/step - loss: 0.1014 - acc: 0.9639 - val_loss: 1.0355e-07 - val_acc: 1.0000
# Epoch 18/20
# 18/18 [==============================] - 3s 172ms/step - loss: 0.1242 - acc: 0.9389 - val_loss: 0.0000e+00 - val_acc: 1.0000
# Epoch 19/20
# 18/18 [==============================] - 3s 175ms/step - loss: 0.1094 - acc: 0.9528 - val_loss: 0.0000e+00 - val_acc: 1.0000
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 20/20
# 18/18 [==============================] - 3s 171ms/step - loss: 0.1253 - acc: 0.9417 - val_loss: 0.0000e+00 - val_acc: 1.0000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        20
#
#     accuracy                           1.00        40
#    macro avg       1.00      1.00      1.00        40
# weighted avg       1.00      1.00      1.00        40
#
# Kfold iteration 6/10
# Total images: 400 ---- Train images: 360 ---- Test images: 40
# Epoch 1/20
# 18/18 [==============================] - 4s 237ms/step - loss: 0.6876 - acc: 0.5194 - val_loss: 0.5904 - val_acc: 0.9000
# Epoch 2/20
# 18/18 [==============================] - 3s 170ms/step - loss: 0.5956 - acc: 0.6889 - val_loss: 16.1632 - val_acc: 0.8250
# Epoch 3/20
# 18/18 [==============================] - 3s 179ms/step - loss: 0.3855 - acc: 0.8250 - val_loss: 34.4502 - val_acc: 0.9000
# Epoch 18/20
# 18/18 [==============================] - 3s 173ms/step - loss: 0.1117 - acc: 0.9694 - val_loss: 24.2210 - val_acc: 0.9500
# Epoch 19/20
# 18/18 [==============================] - 3s 171ms/step - loss: 0.1063 - acc: 0.9528 - val_loss: 24.8557 - val_acc: 0.9500
# Epoch 20/20
# 18/18 [==============================] - 3s 171ms/step - loss: 0.0978 - acc: 0.9667 - val_loss: 25.0647 - val_acc: 0.9500
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        20
#            1       0.95      0.95      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40
#
# Kfold iteration 8/10
# Total images: 400 ---- Train images: 360 ---- Test images: 40
# Epoch 1/20
# 18/18 [==============================] - 4s 241ms/step - loss: 0.6898 - acc: 0.5417 - val_loss: 29.1088 - val_acc: 0.5000
# Epoch 2/20
# 18/18 [==============================] - 3s 169ms/step - loss: 0.5980 - acc: 0.7000 - val_loss: 23.6332 - val_acc: 0.8750
# Epoch 3/20
# 18/18 [==============================] - 3s 182ms/step - loss: 0.3936 - acc: 0.8333 - val_loss: 4.6436 - val_acc: 0.9750
# Epoch 4/20
# 18/18 [==============================] - 3s 178ms/step - loss: 0.2377 - acc: 0.9000 - val_loss: 9.4186 - val_acc: 0.9500
# Epoch 5/20
# 18/18 [==============================] - 3s 181ms/step - loss: 0.1968 - acc: 0.9222 - val_loss: 6.5433 - val_acc: 0.9500
# Epoch 6/20
# 18/18 [==============================] - 3s 178ms/step - loss: 0.1843 - acc: 0.9222 - val_loss: 3.9266 - val_acc: 0.9750
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 7/20
# 18/18 [==============================] - 3s 171ms/step - loss: 0.1394 - acc: 0.9556 - val_loss: 7.2081 - val_acc: 0.9750
# Epoch 8/20
# 18/18 [==============================] - 4s 196ms/step - loss: 0.1288 - acc: 0.9528 - val_loss: 2.8567 - val_acc: 0.9750
# Epoch 9/20
# 18/18 [==============================] - 4s 207ms/step - loss: 0.1348 - acc: 0.9500 - val_loss: 12.1633 - val_acc: 0.9250
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 10/20
# 18/18 [==============================] - 3s 185ms/step - loss: 0.1299 - acc: 0.9500 - val_loss: 3.9845 - val_acc: 0.9750
# Epoch 11/20
# 18/18 [==============================] - 4s 198ms/step - loss: 0.1087 - acc: 0.9583 - val_loss: 7.2026 - val_acc: 0.9750
# Epoch 12/20
# 18/18 [==============================] - 3s 186ms/step - loss: 0.1008 - acc: 0.9639 - val_loss: 3.6480 - val_acc: 0.9750
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 13/20
# 18/18 [==============================] - 3s 192ms/step - loss: 0.1029 - acc: 0.9639 - val_loss: 6.6765 - val_acc: 0.9750
# Epoch 14/20
# 18/18 [==============================] - 3s 192ms/step - loss: 0.1061 - acc: 0.9639 - val_loss: 4.8631 - val_acc: 0.9750
# Epoch 15/20
# 18/18 [==============================] - 3s 179ms/step - loss: 0.1039 - acc: 0.9583 - val_loss: 5.2352 - val_acc: 0.9750
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 16/20
# 18/18 [==============================] - 3s 191ms/step - loss: 0.1015 - acc: 0.9667 - val_loss: 6.6208 - val_acc: 0.9750
# Epoch 17/20
# 18/18 [==============================] - 3s 177ms/step - loss: 0.1052 - acc: 0.9472 - val_loss: 6.9092 - val_acc: 0.9750
# Epoch 18/20
# 18/18 [==============================] - 3s 179ms/step - loss: 0.0985 - acc: 0.9556 - val_loss: 6.2210 - val_acc: 0.9750
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 19/20
# 18/18 [==============================] - 3s 176ms/step - loss: 0.1006 - acc: 0.9528 - val_loss: 4.4483 - val_acc: 0.9750
# Epoch 20/20
# 18/18 [==============================] - 3s 170ms/step - loss: 0.1037 - acc: 0.9583 - val_loss: 5.0121 - val_acc: 0.9750
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98        20
#            1       1.00      0.95      0.97        20
#
#     accuracy                           0.97        40
#    macro avg       0.98      0.97      0.97        40
# weighted avg       0.98      0.97      0.97        40
#
# Kfold iteration 9/10
# Total images: 400 ---- Train images: 360 ---- Test images: 40
# Epoch 1/20
# 18/18 [==============================] - 4s 238ms/step - loss: 0.6965 - acc: 0.5528 - val_loss: 0.5317 - val_acc: 0.8250
# Epoch 2/20
# 18/18 [==============================] - 3s 159ms/step - loss: 0.6065 - acc: 0.7417 - val_loss: 10.4415 - val_acc: 0.9000
# Epoch 3/20
# 18/18 [==============================] - 3s 169ms/step - loss: 0.4296 - acc: 0.8111 - val_loss: 47.1631 - val_acc: 0.8250
# Epoch 4/20
# 18/18 [==============================] - 3s 178ms/step - loss: 0.3113 - acc: 0.8833 - val_loss: 23.6873 - val_acc: 0.9000
# Epoch 5/20
# 18/18 [==============================] - 3s 176ms/step - loss: 0.2657 - acc: 0.8750 - val_loss: 16.1738 - val_acc: 0.9250
# Epoch 6/20
# 18/18 [==============================] - 3s 169ms/step - loss: 0.1816 - acc: 0.9250 - val_loss: 3.3390 - val_acc: 0.9500
# Epoch 7/20
# 18/18 [==============================] - 3s 169ms/step - loss: 0.1930 - acc: 0.9278 - val_loss: 1.9595 - val_acc: 0.9500
# Epoch 8/20
# 18/18 [==============================] - 3s 174ms/step - loss: 0.1446 - acc: 0.9417 - val_loss: 2.3068 - val_acc: 0.9500
# Epoch 9/20
# 18/18 [==============================] - 3s 174ms/step - loss: 0.1428 - acc: 0.9417 - val_loss: 30.9294 - val_acc: 0.8500
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 10/20
# 18/18 [==============================] - 3s 165ms/step - loss: 0.1475 - acc: 0.9389 - val_loss: 3.7368 - val_acc: 0.9750
# Epoch 11/20
# 18/18 [==============================] - 3s 175ms/step - loss: 0.1203 - acc: 0.9472 - val_loss: 4.2511 - val_acc: 0.9750
# Epoch 12/20
# 18/18 [==============================] - 3s 174ms/step - loss: 0.1190 - acc: 0.9528 - val_loss: 7.2223 - val_acc: 0.9750
# Epoch 13/20
# 18/18 [==============================] - 3s 171ms/step - loss: 0.1124 - acc: 0.9472 - val_loss: 1.5503 - val_acc: 0.9750
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 14/20
# 18/18 [==============================] - 3s 174ms/step - loss: 0.1015 - acc: 0.9722 - val_loss: 2.2373 - val_acc: 0.9750
# Epoch 15/20
# 18/18 [==============================] - 3s 187ms/step - loss: 0.0983 - acc: 0.9667 - val_loss: 1.3180 - val_acc: 0.9750
# Epoch 16/20
# 18/18 [==============================] - 3s 175ms/step - loss: 0.0903 - acc: 0.9583 - val_loss: 5.5469 - val_acc: 0.9750
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 17/20
# 18/18 [==============================] - 3s 179ms/step - loss: 0.1050 - acc: 0.9528 - val_loss: 5.0785 - val_acc: 0.9750
# Epoch 18/20
# 18/18 [==============================] - 3s 175ms/step - loss: 0.0890 - acc: 0.9667 - val_loss: 2.8707 - val_acc: 0.9750
# Epoch 19/20
# 18/18 [==============================] - 3s 173ms/step - loss: 0.1041 - acc: 0.9667 - val_loss: 4.2088 - val_acc: 0.9750
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 20/20
# 18/18 [==============================] - 3s 176ms/step - loss: 0.0845 - acc: 0.9750 - val_loss: 2.4566 - val_acc: 0.9750
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98        20
#            1       1.00      0.95      0.97        20
#
#     accuracy                           0.97        40
#    macro avg       0.98      0.97      0.97        40
# weighted avg       0.98      0.97      0.97        40
#
# Kfold iteration 10/10
# Total images: 400 ---- Train images: 360 ---- Test images: 40
# Epoch 1/20
# 18/18 [==============================] - 5s 253ms/step - loss: 0.6611 - acc: 0.6278 - val_loss: 26.2905 - val_acc: 0.6750
# Epoch 2/20
# 18/18 [==============================] - 3s 169ms/step - loss: 0.4673 - acc: 0.8167 - val_loss: 23.2629 - val_acc: 0.9000
# Epoch 3/20
# 18/18 [==============================] - 3s 182ms/step - loss: 0.4100 - acc: 0.8444 - val_loss: 10.7868 - val_acc: 0.9250
# Epoch 4/20
# 18/18 [==============================] - 3s 181ms/step - loss: 0.2420 - acc: 0.9306 - val_loss: 55.6054 - val_acc: 0.9000
# Epoch 5/20
# 18/18 [==============================] - 3s 178ms/step - loss: 0.2136 - acc: 0.9222 - val_loss: 50.6055 - val_acc: 0.9000
# Epoch 6/20
# 18/18 [==============================] - 3s 188ms/step - loss: 0.1899 - acc: 0.9278 - val_loss: 30.2371 - val_acc: 0.9500
# Epoch 7/20
# 18/18 [==============================] - 3s 185ms/step - loss: 0.1617 - acc: 0.9333 - val_loss: 16.8805 - val_acc: 0.9250
# Epoch 8/20
# 18/18 [==============================] - 3s 187ms/step - loss: 0.1562 - acc: 0.9333 - val_loss: 21.2183 - val_acc: 0.9250
# Epoch 9/20
# 18/18 [==============================] - 4s 207ms/step - loss: 0.1811 - acc: 0.9194 - val_loss: 18.6103 - val_acc: 0.9750
# Epoch 10/20
# 18/18 [==============================] - 4s 224ms/step - loss: 0.1198 - acc: 0.9556 - val_loss: 16.5508 - val_acc: 0.9500
# Epoch 11/20
# 18/18 [==============================] - 3s 185ms/step - loss: 0.1394 - acc: 0.9528 - val_loss: 14.0128 - val_acc: 0.9500
# Epoch 12/20
# 18/18 [==============================] - 3s 189ms/step - loss: 0.1653 - acc: 0.9444 - val_loss: 9.4396 - val_acc: 0.9500
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 13/20
# 18/18 [==============================] - 3s 175ms/step - loss: 0.1341 - acc: 0.9611 - val_loss: 13.9925 - val_acc: 0.9750
# Epoch 14/20
# 18/18 [==============================] - 3s 192ms/step - loss: 0.1358 - acc: 0.9444 - val_loss: 11.0922 - val_acc: 0.9750
# Epoch 15/20
# 18/18 [==============================] - 3s 179ms/step - loss: 0.1053 - acc: 0.9611 - val_loss: 14.4425 - val_acc: 0.9750
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 16/20
# 18/18 [==============================] - 3s 181ms/step - loss: 0.1030 - acc: 0.9778 - val_loss: 15.2298 - val_acc: 0.9500
# Epoch 17/20
# 18/18 [==============================] - 3s 182ms/step - loss: 0.0971 - acc: 0.9639 - val_loss: 17.7755 - val_acc: 0.9750
# Epoch 18/20
# 18/18 [==============================] - 3s 179ms/step - loss: 0.1194 - acc: 0.9583 - val_loss: 13.5198 - val_acc: 0.9750
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 19/20
# 18/18 [==============================] - 3s 187ms/step - loss: 0.1028 - acc: 0.9694 - val_loss: 12.5014 - val_acc: 0.9500
# Epoch 20/20
# 18/18 [==============================] - 4s 196ms/step - loss: 0.0919 - acc: 0.9667 - val_loss: 11.3293 - val_acc: 0.9500
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        20
#            1       0.95      0.95      0.95        20
#
#     accuracy                           0.95        40
#    macro avg       0.95      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40

# %%
# We loop over all reports (1 per fold) and then compute the average of all weighted f1 scores
final_f1_score = np.mean([rep['weighted avg']['f1-score'] for rep in reports])

print('Final F1-Score is: {}%'.format(np.round(final_f1_score*100,2)))
# Out:
# Final F1-Score is: 96.49%
